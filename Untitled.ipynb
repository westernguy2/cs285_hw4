# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
run1 = [-739.9501953125, -349.6996154785156, -260.27886962890625, -252.20001220703125, -588.9815673828125, -271.16766357421875, -281.1348571777344, -262.0748291015625, -464.4216613769531, -301.7567138671875, -266.2303161621094, -284.8792724609375, -435.8495788574219, -277.2024841308594, -284.55340576171875]
run2 = [-379.58782958984375, -296.34063720703125, -283.733642578125, -270.54852294921875, -264.8086853027344, -282.1412658691406, -277.51641845703125, -304.24853515625, -277.87884521484375, -277.5742492675781, -310.193115234375, -282.357666015625, -283.4879150390625, -287.3594970703125, -276.39141845703125]
run3 = [-460.1689453125, -370.9910583496094, -337.0758361816406, -333.02685546875, -397.0563049316406, -399.5177307128906, -341.838134765625, -423.048095703125, -313.67022705078125, -336.7093505859375, -336.17523193359375, -325.26007080078125, -345.059814453125, -337.560791015625, -347.8011169433594]
run4 = [-518.0750732421875, -299.70721435546875, -358.27972412109375, -374.3020324707031, -314.8544921875, -310.82659912109375, -309.7933044433594, -311.4015808105469, -289.2333679199219, -322.4525146484375, -285.7448425292969, -288.1407470703125, -297.74554443359375, -291.80841064453125, -343.68438720703125]
run5 = [-406.3643798828125, -295.68353271484375, -284.7417907714844, -320.34295654296875, -277.16851806640625, -265.19384765625, -277.93719482421875, -309.36224365234375, -266.8796081542969, -241.40419006347656, -272.1106262207031, -274.2911071777344, -245.89089965820312, -242.96401977539062, -275.8402404785156]
run6 = [-502.006591796875, -325.19921875, -348.94171142578125, -287.3824462890625, -267.17529296875, -264.64105224609375, -280.83148193359375, -292.94134521484375, -306.9630126953125, -258.08343505859375, -264.6729736328125, -262.7075500488281, -308.9286804199219, -249.51864624023438, -271.8551330566406]
run7 = [-406.3643798828125, -295.68353271484375, -284.7417907714844, -320.34295654296875, -277.16851806640625, -265.19384765625, -277.93719482421875, -309.36224365234375, -266.8796081542969, -241.40419006347656, -272.1106262207031, -274.2911071777344, -245.89089965820312, -242.96401977539062, -275.8402404785156]
run8 = [-420.8464660644531, -276.48175048828125, -296.7244873046875, -271.79840087890625, -249.19775390625, -254.6249542236328, -257.73968505859375, -290.408935546875, -253.31729125976562, -243.011474609375, -252.3128204345703, -264.3622131347656, -248.70034790039062, -241.1147003173828, -260.0660095214844]

# %%
run1_str = 'horizon = 5'
run2_str = 'horizon = 15'
run3_str = 'horizon = 30'
run4_str = 'numseq = 100'
run5_str = 'numseq = 1000'
run6_str = 'ensemble = 1'
run7_str = 'ensemble = 3'
run8_str = 'ensemble = 5'

# %%
plt.plot(np.arange(15), run1, label=run1_str)
plt.plot(np.arange(15), run2, label=run2_str)
plt.plot(np.arange(15), run3, label=run3_str)
plt.legend()
plt.xlabel('iteration number')
plt.ylabel('Average Eval Return')
plt.title('Comparing Horizon values');

# %%
plt.plot(np.arange(15), run4, label=run4_str)
plt.plot(np.arange(15), run5, label=run5_str)
plt.legend()
plt.xlabel('iteration number')
plt.ylabel('Average Eval Return')
plt.title('Comparing Number of Candidate Action Sequences');

# %%
plt.plot(np.arange(15), run6, label=run6_str)
plt.plot(np.arange(15), run7, label=run7_str)
plt.plot(np.arange(15), run8, label=run8_str)
plt.legend()
plt.xlabel('iteration number')
plt.ylabel('Average Eval Return')
plt.title('Comparing Ensemble Size');

# %%
q5_run1 = [142.1214599609375, 295.2508850097656, 278.25244140625, 305.3361511230469, 274.83880615234375]
q5_run2 = [187.135986328125, 407.0489501953125, 392.00836181640625, 449.76654052734375, 462.39752197265625]
q5_run3 = [234.26161193847656, 502.06890869140625, 710.553955078125, 866.7042846679688, 631.080078125]

# %%
q5_run1_str = 'random'
q5_run2_str = 'cem = 2'
q5_run3_str = 'cem = 4'

# %%
plt.plot(np.arange(5), q5_run1, label=q5_run1_str)
plt.plot(np.arange(5), q5_run2, label=q5_run2_str)
plt.plot(np.arange(5), q5_run3, label=q5_run3_str)
plt.legend()
plt.xlabel('iteration number')
plt.ylabel('Average Eval Return')
plt.title('Comparing CEM with Random');
